# %%
import os
import base64
from IPython.display import display, HTML

# %%
def encode_image(image_path):
  with open(image_path, "rb") as image_file: # binary 형태로 이미지 파일 열기
    f = image_file.read() 
    f_encoded = base64.b64encode(f)
    return f_encoded.decode('utf-8')

# %%
img_path = "./data/cow.jpeg"
encoded_image_res1 = encode_image(img_path)

# %%
# HTML display
# Create an HTML img tag with the Base64 encoded image
image_html = f'<img src="data:image/jpeg;base64,{encoded_image_res1}" alt="Base64 encoded image" />'

# Display the image
display(HTML(image_html))
# Out:
# <img src="data:image/jpeg;base64,..." alt="Base64 encoded image" />

# %%
from openai import OpenAI
client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY", ""))

# %%
response = client.chat.completions.create(
  model="gpt-4-turbo",
  messages=[
    {
      "role": "user",
      "content": [
        {
          "type": "text",
          "text": "사진에 뭐가 보여? 풍경을 설명해줘.",
        },
        {
          "type": "image_url",
          "image_url": {
            "url": f"data:image/jpeg;base64,{encoded_image_res1}",  # website image url
          },
        }
      ],
    }
  ],
  max_tokens=1000,
)

# %%
print(response.choices[0].message.content)
# Out:
# 사진은 아름다운 시골 풍경을 보여줍니다. 사진에는 초록색 풀밭에서 풀을 뜯고 있는 소 몇 마리가 보입니다. 사진의 배경에는 해질 녘 하늘을 비추는 태양의 빛이 구름 사이로 비치며 멋진 광경을 연출하고 있어요. 이외에도 사진 오른쪽에는 회색의 벽이 보이며, 벽 너머로는 바다와 수평선이 약간 보입니다. 전체적으로 평화롭고 자연스러운 분위기의 풍경입니다.

# %%
img_path = "./data/waterfall.JPG"
encoded_image_res2 = encode_image(img_path)

response = client.chat.completions.create(
  model="gpt-4-turbo",
  messages=[
    {
      "role": "user",
      "content": [
        {
          "type": "text",
          "text": "여기는 어느 나라의 어느 관광 명소야?.",
        },
        {
          "type": "image_url",
          "image_url": {
            "url": f"data:image/jpeg;base64,{encoded_image_res2}",
          },
        }
      ],
    }
  ],
  max_tokens=1000,
)
print(response.choices[0].message.content)
# Out:
# 이 사진은 라오스의 유명한 관광 명소인 꽝시 폭포(Kuang Si Falls)를 보여줍니다. 이 아름다운 폭포는 라오스 루앙프라방에서 남쪽으로 약 29킬로미터 떨어진 곳에 위치해 있으며, 그 특징적인 푸른 빛깔의 물과 여러 단계로 흐르는 폭포로 유명합니다. 방문자들은 이곳에서 수영을 하거나 주변의 자연 경관을 즐기며 휴식을 취할 수 있습니다.

# %%
img_path = "./data/christmas_market.jpeg"
encoded_image_res2 = encode_image(img_path)

response = client.chat.completions.create(
  model="gpt-4-turbo",
  messages=[
    {
      "role": "user",
      "content": [
        {
          "type": "text",
          "text": "그럼 여기는 어느 나라의 어느 관광 명소야?.",
        },
        {
          "type": "image_url",
          "image_url": {
            "url": f"data:image/jpeg;base64,{encoded_image_res2}",
          },
        }
      ],
    }
  ],
  max_tokens=1000,
)
print(response.choices[0].message.content)
# Out:
# 이 사진은 크리스마스 시장을 보여주고 있어요. 크리스마스 트리와 전통적으로 장식된 부스들이 있네요. 사진에 나와 있는 파라솔의 글자를 보면 "ALMBOCK Trachten"이라고 적혀 있어서, 이것은 독일 또는 오스트리아에 있을 가능성이 높은, 전통적인 독일어 사용 지역과 관련이 있을 수 있습니다. 이런 크리스마스 마켓은 유럽에서 특히 인기가 많고, 많은 도시에서 개최됩니다. 하지만 구체적으로 어느 도시인지는 추가 정보가 없어 확실히 말씀드리기 어렵습니다.
