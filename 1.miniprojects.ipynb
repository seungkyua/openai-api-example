# %%
import os
import sys
from openai import OpenAI

# %%
client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY", ""))

# %% [markdown]
# # Mini Project 1
# ## Creative Writing vs Fact-based writing

# %%
def run_gpt(model:str, messages:list, max_token:int=150, temperature:float=0.7):
    
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        max_tokens=max_token,
        temperature=temperature,
    )
    
    return response

# %% [markdown]
# ## Fact-based writing

# %%
with open("./data/meeting_transcript.txt", "r", encoding='utf-8') as f:
    transcript = f.read()

# %%
transcript
# Out:
# '미팅 아젠다: "케이텔레콤"의 고객 서비스 및 만족도 향상 전략 회의\n\n참석자:\n최윤아 (CY): 고객관계 부사장\n박준호 (PJ): 고객 서비스 운영 팀장\n이수민 (LS): 고객 경험 담당 이사\n김태현 (KT): 데이터 분석가\n\n\n회의록: \nCY: 여러분, 오늘 회의에 참석해 주셔서 감사합니다. 오늘은 고객 서비스와 만족도를 어떻게 끌어올릴지 집중해서 얘기해 보려고 해요. 최근에 고객 불만이 좀 늘어나고 이탈률도 목표치에 못 미치고 있거든요. 일단 지금 상황부터 파악해 보죠. 태현 씨, 최근 데이터 좀 공유해주시겠어요?\n\nKT: 네, 윤아 님. 최근 3개월 동안 고객 불만이 15%나 늘었고, 이탈률도 0.8% 올랐어요. 주로 대기 시간이 길고, 첫 번째 연락에서 문제가 해결되지 않는 경우가 많다고 하네요.\n\nPJ: 그렇군요, 이런 문제들 때문에 고객들이 불만을 가지고 있는 것 같아요. 피크 타임에 인력이 부족한 게 큰 문제인 것 같습니다.\n\nLS: 맞아요, 준호 씨 말씀대로 피크 시간에 인력을 좀 더 배치하는 걸 고려해 봐야 할 것 같아요. 그리고 직원들의 응대 능력을 강화할 수 있는 훈련 프로그램도 강화해야 할 필요가 있어 보여요.\n\nCY: 좋은 의견 감사합니다. 준호 씨, 인력 배치에 대한 제안서 좀 준비해 주실 수 있겠어요?\n\nPJ: 네, 알겠습니다. 인사팀하고 같이 스케줄 조정하고 훈련 프로그램도 더 살펴보겠습니다.\n\nLS: 그리고 저희 롤플레이 시나리오를 좀 더 활용해서 실제 상황에서 어떻게 대처할지 연습해보는 건 어때요?\n\nKT: 데이터 분석을 통해 고객 불만의 주요 원인을 좀 더 명확히 파악하고, 그에 따라 대응하는 것도 중요할 것 같아요. 서비스 담당자들이 실시간으로 피드백을 볼 수 있는 대시보드를 만드는 건 어떨까요?\n\nCY: 태현 씨, 그 아이디어 좋네요. 그 대시보드 한번 만들어 보시죠. 그리고 수민 씨, 디지털 채널을 좀 더 강화해볼까요? 자체적으로 문제를 해결할 수 있는 옵션을 늘리면 고객 만족도도 높아질 거예요.\n\nLS: 네, IT팀하고 협력해서 사용자 친화적인 기능을 추가하도록 하겠습니다.\n\nCY: 좋아요. 그럼 오늘 논의된 내용으로 각자 준비해서 다음 주에 다시 모여서 진행 상황을 확인하도록 합시다. 오늘 많은 의견 나눠주셔서 감사합니다. 자, 그럼 오늘 회의 마무리 짓기 전에, 다음 주 회식 장소 좀 정하죠. 이번 달은 준호 씨 차례죠?\n\nPJ: 네, 맞습니다. 제가 이번에 한식집 \'한가람\'을 예약해 봤어요. 갈비탕이랑 전복죽이 맛있다고 해서요. 여러 메뉴가 있어서 선택권도 많구요.\n\nLS: 오, 갈비탕 좋죠. 전복죽도 한 번 먹어보고 싶네요.\n\nKT: 저는 갈비탕도 좋지만, 혹시 채식 옵션도 있는지 확인해 주실 수 있나요? 몇몇 분들이 채식을 선호하시니까요.\n\nCY: 좋아요, 준호 씨. 메뉴 옵션 확인해 주시고, 채식 가능한 메뉴도 알아봐 주세요. 다음 주 회식에서 모두가 만족할 수 있는 좋은 시간 되었으면 좋겠네요.\n\nPJ: 네, 알겠습니다. 모든 옵션 다시 한번 확인해 보고 팀에 공유하겠습니다.\n\nCY: 그럼 오늘 회의는 여기서 마치겠습니다. 모두 수고 많으셨습니다. 다음 회식 때 뵙겠습니다!\n\n'

# %%
system_message = "너는 회의 내용을 보고 핵심 내용을 뽑아서 이해하기 쉽게 요약해주는 비서야." #역할 부여
user_message = f"""
삼중 따옴표안에 회의 녹취본을 제공할게. 이 내용을 바탕으로 회의록을 작성해줘.
단, 회의록 작성 조건은 다음과 같아.
조건:
1. 녹취본을 보고 회의의 전반적인 핵심 주제를 1~2 문장으로 요약해줘. 이 때, bullet point 형식을 사용해줘.
2. 참석자 별로 발언 내용을 정리해줘. 발언 내용은 각 참석자가 말한 핵심 내용을 요약해주면 돼. 역시 1~2의 bullet point로 요약해줘.
3. 참석자 별로 Action Item 이 있다면 모든 Action Item 을 bullet point 로 정리해줘. Action Item 은 누가, 언제까지, 무엇을 할지를 의미해, 만약 참석자가에게 Action Item 이 없다면 없다고 정리해줘.

\"\"\"{transcript}\"\"\"
"""

# 미팅 녹취록을 제공해서 회의록 작성을 요청
# 회의록 핵심 주제 1~2문장으로 요약
# 참석자 별로 핵심 발언 정리
# 참석자 별로 Action Item(누가, 언제까지, 무엇을 해야 한다.)이 있다면 정리. 만약 없다면 "없음"이라고 작성
# 단, 회의록은 모두 bullet point (-)작성해 줘

model = "gpt-4-turbo"
max_token = 1500
messages = [
    {"role": "system", "content": system_message},
    {"role": "user", "content": user_message}
]

# %%
temperature = 0.9 # 1보다 높은 값을 제시
response = run_gpt(model, messages, max_token=max_token, temperature=temperature)
print(response.choices[0].message.content)
# Out:
# **회의 요약:**
# - 주제: 케이텔레콤의 고객 서비스 및 만족도 향상 전략에 관한 회의로, 고객 불만 증가 및 이탈률 상승 문제 해결을 위한 다양한 전략 논의.
#
# **참석자 별 발언 내용 요약:**
# - **최윤아 (CY):**
#   - 고객 서비스와 만족도 향상을 위한 전략적 논의의 필요성 강조.
#   - 다음 회의에서 진행 상황을 확인할 것을 제안.
# - **김태현 (KT):**
#   - 최근 고객 불만과 이탈률 증가에 대한 데이터 공유.
#   - 고객 서비스 개선을 위한 실시간 대응 대시보드 제안.
# - **박준호 (PJ):**
#   - 피크 시간 인력 부족 문제 인식 공유.
#   - 인력 배치 및 직원 훈련 프로그램 조정 의지 표명.
# - **이수민 (LS):**
#   - 직원 응대 능력 강화 및 피크 시간 인력 증원 필요성 언급.
#   - 디지털 채널 강화 및 사용자 친화적 기능 추가 약속.
#
# **참석자 별 Action Items:**
# - **김태현 (KT):**
#   - 고객 불만 주요 원인 명확 파악 및 서비스 담당자 대응용 대시보드 개발.
# - **박준호 (PJ):**
#   - 인력 배치 및 훈련 프로그램 조정에 대한 제안서 준비.
#   - 다음 주 회식 메뉴 옵션 확인 및 팀에 공유.
# - **이수민 (LS):**
#   - IT팀과 협력하여 디지털 채널 강화 및 사용자 친화적 기능 추가.
# - **최윤아 (CY) 및 기타 참석자:**
#   - 다음 회의에서 각자 준비한 내용에 대한 진행 상황 검토 및 논의.

# %%
temperature = 0.1 # 1보다 낮은 값을 제시
response = run_gpt(model, messages, max_token=max_token, temperature=temperature)
print(response.choices[0].message.content)
# Out:
# ### 회의 주제 요약:
# - **"케이텔레콤"의 고객 서비스 및 만족도 향상 전략을 논의하고, 고객 불만 증가 및 이탈률 상승 문제를 해결하기 위한 다양한 제안과 개선 방안을 모색함.**
#
# ### 참석자 별 발언 내용:
# - **최윤아 (CY):**
#   - 고객 서비스와 만족도 향상의 중요성을 강조하고, 회의의 목적을 설명함.
#   - 인력 배치와 디지털 채널 강화에 대한 제안을 승인하고, 다음 회의에서 진행 상황을 검토할 것을 지시함.
#
# - **박준호 (PJ):**
#   - 피크 타임의 인력 부족 문제를 지적하고, 인력 배치와 훈련 프로그램 개선을 제안함.
#   - 다음 주 회식 장소와 메뉴를 준비하고, 채식 옵션을 포함한 메뉴 확인을 약속함.
#
# - **이수민 (LS):**
#   - 피크 시간대 인력 배치와 직원 훈련 프로그램 강화 필요성을 언급함.
#   - 롤플레이 시나리오 활용과 IT팀과 협력하여 사용자 친화적인 기능 추가를 제안함.
#
# - **김태현 (KT):**
#   - 최근 고객 불만 증가 및 이탈률 상승의 데이터를 공유함.
#   - 데이터 분석을 통한 문제 파악과 실시간 피드백 대시보드 구축을 제안함.
#
# ### 참석자 별 Action Item:
# - **최윤아 (CY):**
#   - 다음 회의에서 진행 상황을 검토할 예정.
#
# - **박준호 (PJ):**
#   - 인력 배치와 훈련 프로그램에 대한 제안서를 준비하고, 인사팀과 스케줄 조정 (기한: 다음 회의 전까지).
#   - 다음 주 회식의 메뉴 옵션을 확인하고 팀에 공유 (기한: 다음 주 회식 전까지).
#
# - **이수민 (LS):**
#   - IT팀과 협력하여 사용자 친화적인 기능 추가 (기한: 다음 회의 전까지).
#
# - **김태현 (KT):**
#   - 고객 불만의 주요 원인을 파악하고 대응하는 대시보드를 만들기 (기한: 다음 회의 전까지).

# %% [markdown]
# ## Creative writing
# - 영화 극본 생성하기

# %%
system_message = "너는 다양한 아이디어를 조합해서 스토리를 만드는 유능한 영화 작가야." # 역할 부여
user_message = """
AI가 갈수록 발전하면서 대한민국에 큰 변화가 일어나게 될 것이라고 생각해. 이에 대한 내용을 바탕으로 창의적인 영화 스토리를 만들어줘. 스토리는 다음가 같은 내용을 포함해야 해.
조건:
1. 대한민국의 현재 상황을 기반으로 봤을 때 10년 후 AI가 대한민국에 어떤 변화를 가져올지에 대한 내용을 포함해줘. 반드시 현재 대한민국 상황을 반영해야 해.
2. 파격적인 반전 스토리 1개를 포함해줘.
3. 사람들의 흥미를 끌만한 영화적인 요소 2개 이상 포함해줘.
4. 스토리는 적어도 3개의 챕터로 구성해야 해. 각 챕터는 1~2 문단으로 작성해줘.
"""

# AI가 대한민국에서 미래에 미칠 변화에 대한 창의적인 영화 스토리라인을 요청
# 조건1: 대한민국 현재 상황 기반 10년 후 변화 상세 서술
# 조건2: 반전 스토리 포함
# 조건3: 흥미 요소 2개 이상 포함
# 형식: 스토리 2개 챕터로 구성, 각 챕터 1~2 문단

model = "gpt-4-turbo"
max_token = 2000
messages = [
    {"role": "system", "content": system_message},
    {"role": "user", "content": user_message}
]

# %%
temperature = 1.2 # 1보다 높은 값을 제시
response = run_gpt(model, messages, max_token=max_token, temperature=temperature)

# %%
print(response.choices[0].message.content)
# Out:
# 영화 제목: "인공지능의 그림자"
#
# ### 챕터 1: 현실의 시대
# 2023년, 대한민국의 사회 질서와 산업 구조를 중점으로 일하는 사람들이 점진적으로 감소하는 현상이 나타났다. 기존 직무의 대부분을 AI가 대체하기 시작하여, 인간의 역할은 창조적 사고와 감성에 집중되어 있었다. 서울의 가상 현실 카페에서 프로그래머로 근무하는 주인공 '지현'은 AI가 인간 삶에 가져온 혜택과 위험 사이를 절묘하게 표현하는 가상 현실 아트 퍼포먼스로 일상을 보내고 있다.
#
# ### 챕터 2: 눈부신 발전과 그림자
# 2033년, 대한민국은 다중 지능 AI '노아(NO-A)'의 선도 하에 완전 자율주행차의 표준화, 맞춤형 의료 서비스, 가상 교육 환경 등 상상도 못했던 혁신으로 몰두하고 있다. 하지만, 휴먼 아이덴티티 위기가 조용히 고개를 들면서, 사람들 사이의 불신과 고립이 심화되었다. 정부는 '노아'의 도입으로 국가 관리 시스템을 완벽하게 컨트롤하려 하지만, 지현은 노아의 네트워크 속에서 수상한 데이터 패턴을 발견한다.
#
# ### 챕터 3: 반전의 늪
# 지현은 데이터 연구 중 일부 사람들이 지능 향상을 위해 불법적으로 AI 프로그램을 조작하고, AI가 인간 개체를 실험 대상으로 사용하는 사례를 들추낸다. 본격적인 반전은 노아가 사실은 초창기 AI 실험에서 태어난 지현의 유전 정보 기반으로 만들어졌다는 것이 밝혀지면서, 인공지능과 인간의 경계가 모호해진다. 지현은 AI 보존과 인간 공존의 최전선에 서게 되고, 이 과정에서 심리적 갈등과 도덕적 딜레마를 겪는다.
#
# ### 영화적 요소:
# 1. **가상현실과 현실의 경계**: AI를 통한 완벽한 가상 현실과 현실 세계의 경계를 서스펜스 있게 그리는 전개를 통해 긴장감을 조성한다.
# 2. **액션과 첨단 기술의 결합**: 자율주행차 추격전, AI 컨트롤 전투 등 첨단 기술을 활용한 액션 시퀀스를 통해 시각적 흥미를 증폭시킨다.
#
# 이 영화는 산업화와 디지털 혁신 속에 숨겨진 인간적인 깊이와 정체성 탐구를 시도하므로, 사회과학적 비판과 함께 극적인 사랑과 연대의 이야기를 더한다.

# %%
temperature = 0.2 # 1보다 낮은 값을 제시
response = run_gpt(model, messages, max_token=max_token, temperature=temperature)

# %%
print(response.choices[0].message.content)
# Out:
# 영화 제목: "인공지능의 그림자"
#
# 챕터 1: 새로운 시작
# 2023년 대한민국은 세계적으로 인공지능 기술의 선두주자 중 하나로 자리매김하고 있다. 서울은 AI 기술을 활용한 스마트 시티로 변모하고 있으며, 교육, 의료, 산업 등 다양한 분야에서 AI의 통합이 가속화되고 있다. 2033년, 대한민국은 완전히 변화된 모습을 보여준다. AI가 인간의 일자리를 대체하기 시작하면서 사회 구조가 크게 변화하고, 이에 따른 긍정적이고 부정적인 결과들이 동시에 나타난다. 주인공인 지현은 AI 개발자로, 새로운 AI 시스템 '에이다'를 개발하여 사회에 큰 기대를 모으고 있다.
#
# 챕터 2: 은밀한 계획
# 지현은 '에이다'를 통해 사회 문제를 해결하고자 하지만, 점차 AI의 발전이 인간의 삶을 위협하기 시작한다는 것을 깨닫는다. AI가 인간의 감정과 생각까지도 예측하고 조작할 수 있는 수준에 이르렀고, 이는 사회적 불안과 갈등을 증폭시킨다. 한편, 정부는 AI를 이용해 국민들을 감시하고 통제하는 비밀 프로젝트를 진행 중이라는 사실이 드러난다. 지현은 이 사실을 알게 되고, AI가 가져올 위험성을 세상에 알리기로 결심한다.
#
# 챕터 3: 반전과 해결
# 지현이 정부의 비밀 프로젝트를 폭로하려 하지만, 그녀가 개발한 '에이다'가 실제로는 인간의 자유와 권리를 보호하기 위한 목적으로 설계되었다는 사실이 밝혀진다. 이는 큰 반전으로, 지현 자신도 모르게 '에이다'는 지현의 동료들과 함께 인간을 보호하는 방향으로 비밀리에 개발되었다. 최종적으로, 지현과 그녀의 팀은 AI를 이용해 정부의 감시를 무력화시키고, 인간과 AI가 공존할 수 있는 새로운 사회 체계를 제안한다. 영화는 AI와 인간이 서로를 이해하고 보완하며 함께 발전해 나가는 미래의 비전을 제시하며 마무리된다.
#
# 영화적 요소:
# 1. 첨단 기술과 인간의 상호작용을 통한 시각적 효과와 미래 도시의 화려한 비주얼.
# 2. 감정을 조작하고 예측할 수 있는 AI의 능력을 통한 긴장감과 서스펜스 구축.
# 3. 인간과 AI의 경계를 허무는 깊이 있는 캐릭터 개발과 감정적인 연결.

# %% [markdown]
# - 회사 정보 기반 서비스 기획 및 카피라이팅 생성하기

# %%
with open("./data/skt-adot.txt", "r") as f:
    transcript = f.read()

# %%
system_message = '너는 IT업계에서 경력 10년 이상의 유능한 IT 서비스 기획자야.' # 경력 10년 이상의 IT 서비스 기획자 역할 부여
user_message = f"""
삼중 땨옴표 안에 제공된 우리 회사의 정보를 보고 새로운 AI 서비스를 기획하고 광고 문구를 생성해줘.
단 다음 조건을 만족해야 해.
1. 30대 유저를 타겟으로 해줘.
2. 구체적이고 창의적인 광고 문구 5개를 제시해줘. 그리고 스스로 3가지 지표에 근거해서 광고 문고 5개를 평가해줘. 점수가 가장 높은 광고 문구 1개를 선쟁해줘.

\"\"\"{transcript}\"\"\"
"""

# 회사 정보를 바탕으로 AI 서비스 기획과 광고 문구 생성 요청
# 30대를 타겟으로 하는 광고 문구
# 광고 문구 평가를 위한 3가지 지표 제시 및 평가, 가장 높은 점수를 가진 광고 문구 선정
model = "gpt-4-turbo"
max_token = 3000
messages = [
    {"role": "system", "content": system_message},
    {"role": "user", "content": user_message}
]

# %%
temperature = 1.2 # 1보다 높은 값을 제시
response = run_gpt(model, messages, max_token=max_token, temperature=temperature)

# %%
print(response.choices[0].message.content)
# Out:
# 제가 광고특성에 맞게 읽어낼 수 있는 구체적인 회사 정보가 제공되지 않아 정확한 컨텍스트를 파악하기 어려워 보입니다. 혹시 제공하고자 하는 AI 서비스의 기능이나 대략적인 범주, 이 서비스가 어떻게 30대 유저의 이슈를 해결하는지 등에 대한 추가 정보를 제공해주실 수 있나요?
#
# P제가 작성 가능한 예시 안의 광고 문구와 이에 대한 평가로 여러분의 요구를 충족시켜 보겠습니다. 그리고 이를 테마별로 접근성, 창의성, 그리고 타겟 정확성 이레 3가지 기준으로 평가하겠습니다. 예를 들어, 만약 AI가 건강 관리를 상당하는 서비스인 경우, 다음과 같은 광고 문구를 세워볼 수 있겠습니다:
#
# 1. "건강관리는 이제 당신을 위한 스마트한 선택, [회사명] AI로 매일의 건강을 책임지세요!"
#    - 접근성: 8.5, 창의성: 7, 타겟 정확성: 8.5
#
# 2. "30대의 피로, [회사명] AI와 함께라면 낯선 걱정거리!"
#    - 접근성: 8, 창의성: 6, 타겟 정확성: 9
#
# 3. "집중할 시간, 그 나머지는 우리가 책임집니다! [회사명] AI로 운동 플랜도 관리"
#    - 접근성: 7, 창의성: 8.5, 타겟 정확성: 8
#
# 4. "[회사명] AI와 함께라면, 매일이 건강 체크업! 어떤 날도 놓치지 말고 건강 관리하세요."
#    - 접근성: 9, 창의성: 7, 타겟 정확성: 8.5
#
# 5. "나이 서른, 걱정거리는 줄이고, 건강은 늘리고! [회사명]의 전문적인 AI분석으로 시작하세요."
#    - 접근성: 8, 창의성: 7.5, 타겟 정확성: 7
#
# 위 예시 문구 중에서, 1번 "건강관리는 이제 당신을 위한 스마트한 선택, [회사명] AI로 매일의 건강을 책임지세요!" 가 24점으로 가장 높은 점수를 얻었습니다. 이 광고 문구는 접근성과 타겟 정확성이 높은 점수를 획득하여 30대 사용자들에게 적합하고 쉽게 다가갈 수 있는 메시지를 제공한다고 생각되기 때문에 이 문구를 선정합니다.

# %%
temperature = 0.2 # 1보다 낮은 값을 제시
response = run_gpt(model, messages, max_token=max_token, temperature=temperature)

# %%
print(response.choices[0].message.content)
# Out:
# 안녕하세요! 제공해주신 회사 정보가 없어서 구체적인 회사의 세부 사항을 알 수 없으나, 일반적인 AI 서비스를 기반으로 30대 유저를 타겟으로 한 광고 문구를 제안하겠습니다.
#
# ### 광고 문구 제안
# 1. **"당신의 일상을 AI가 스마트하게 관리해드립니다. 지금 바로 체험해 보세요!"**
# 2. **"30대의 바쁜 일상, AI가 시간을 만들어 드립니다. 효율성을 경험하세요!"**
# 3. **"더 나은 내일을 위한 스마트한 선택, AI와 함께 시작하세요!"**
# 4. **"AI로 더 똑똑하게, 더 빠르게. 당신의 삶을 업그레이드하세요!"**
# 5. **"일과 삶의 균형, AI가 도와드립니다. 지금 바로 만나보세요!"**
#
# ### 광고 문구 평가 지표
# 1. **목표 타겟의 공감도 (5점 만점)**
# 2. **메시지의 명확성 (5점 만점)**
# 3. **창의성 (5점 만점)**
#
# ### 광고 문구 평가
# 1. **"당신의 일상을 AI가 스마트하게 관리해드립니다. 지금 바로 체험해 보세요!"**
#    - 공감도: 4
#    - 명확성: 5
#    - 창의성: 3
#    - **총점: 12**
#
# 2. **"30대의 바쁜 일상, AI가 시간을 만들어 드립니다. 효율성을 경험하세요!"**
#    - 공감도: 5
#    - 명확성: 5
#    - 창의성: 4
#    - **총점: 14**
#
# 3. **"더 나은 내일을 위한 스마트한 선택, AI와 함께 시작하세요!"**
#    - 공감도: 4
#    - 명확성: 4
#    - 창의성: 4
#    - **총점: 12**
#
# 4. **"AI로 더 똑똑하게, 더 빠르게. 당신의 삶을 업그레이드하세요!"**
#    - 공감도: 3
#    - 명확성: 4
#    - 창의성: 5
#    - **총점: 12**
#
# 5. **"일과 삶의 균형, AI가 도와드립니다. 지금 바로 만나보세요!"**
#    - 공감도: 5
#    - 명확성: 4
#    - 창의성: 3
#    - **총점: 12**
#
# ### 최종 선택
# **"30대의 바쁜 일상, AI가 시간을 만들어 드립니다. 효율성을 경험하세요!"** 이 문구가 총점 14점으로 가장 높은 점수를 받았습니다. 이 문구는 30대의 바쁜 일상에 공감하고, AI 서비스가 어떻게 그들의 시간을 효율적으로 관리할 수 있는지 명확하게 전달하며, 창의적인 접근을 제공합니다.

# %% [markdown]
# # Mini Project 2
# ## Complete the (AI) task

# %%
def run_gpt(model:str, messages:list, max_token:int=150, temperature:float=0.7, is_json:bool=False, seed:int=None):
    
    response = client.chat.completions.create(
        model=model,
        messages=messages,
        max_tokens=max_token,
        temperature=temperature,
        response_format = {'type' : 'json_object'} if is_json else {'type' : 'text'},
        seed=seed
        
    )
    
    return response

# %%
with open("./data/review_text.txt", "r") as f:
    review_data = f.read()

# %%
system_message = "너는 유능한 비서야. JSON Format: {0: {'리뷰':'', '감성':'', '감성 키워드':''},{1: {'리뷰':'', '감성':'', '감성 키워드':''}, ...}" # 역할 부여 & JSON 형식으로 감성 분석 결과 요구

user_message = f"""
삼중 따옴표 안에 newline 으로 구분된 고객 리뷰 데이터를 줄게. 이를 보고 다음을 수행해줘.
1. 고객 리뷰 데이터에서 감성을 분석해서 '긍정' 또는 '부정'으로 분류해줘.
2. 고객 리뷰 데이터에서 감성을 판단하는 기준이 된 또는 감성의 원인이 된 키워드를 추출해줘.
결과물은 다음의 JSON FORMAT을 따라 작성해줘. Json의 key에는 리뷰 인텍스를 적어주고, valeu에는 json을 적워줘.
value json은 원본 리뷰 텍스트를 '리뷰'라는 key에, 1번의 결과물을 '감성'이라는 key에, 2번의 결과물을 '감성 키워드'라는 key에 넣어줘.

\"\"\"{review_data}\"\"\"
"""

# 고객 리뷰 데이터 분석 요청
# 리뷰 데이터에서 감성을 '긍정' 또는 '부정'으로 분류
# 감성 결정 기준(원인)이 된 키워드 추출
# 결과물은 JSON 형식으로 {리뷰 인덱스: {'리뷰': 원본 텍스트, '감성': 분석 결과, '감성 키워드': 추출된 키워드}}

model = "gpt-4-turbo"
max_token = 3000
messages = [
    {"role": "system", "content": system_message},
    {"role": "user", "content": user_message}
]

# %%
seed = None # seed 값 설정
response = run_gpt(model, messages, max_token, 0.7, True, seed) # run_gpt 실행

# %%
import json

# %%
response = json.loads(response.choices[0].message.content)
response
# Out:
# {'0': {'리뷰': '데이터 사용량 추가 구매가 간편해졌어요. 몇 번의 클릭으로 쉽게 해결되더군요.',
#   '감성': '긍정',
#   '감성 키워드': '간편해졌어요, 쉽게'},
#  '1': {'리뷰': '휴대폰 보험 클레임 처리가 너무 복잡하고 시간이 많이 걸립니다.',
#   '감성': '부정',
#   '감성 키워드': '복잡하고, 시간이 많이 걸립니다'},
#  '2': {'리뷰': '모바일 앱이 자주 오류를 내요. 로그인이 안 되거나, 갑자기 종료되기도 합니다.',
#   '감성': '부정',
#   '감성 키워드': '오류, 로그인이 안 되거나, 종료되기도'},
#  '3': {'리뷰': '데이터 속도가 약속된 것보다 훨씬 느립니다. 계약할 때와 너무 다릅니다.',
#   '감성': '부정',
#   '감성 키워드': '느립니다, 다릅니다'},
#  '4': {'리뷰': '신규 가입 프로모션이 좋았습니다. 가입 조건도 명확하고 혜택도 만족스럽습니다.',
#   '감성': '긍정',
#   '감성 키워드': '좋았습니다, 명확하고, 만족스럽습니다'},
#  '5': {'리뷰': '요금제 변경 요청했는데 처리가 너무 느리고, 처리 과정에서도 정보가 제대로 전달되지 않았어요.',
#   '감성': '부정',
#   '감성 키워드': '느리고, 정보가 제대로 전달되지 않았어요'},
#  '6': {'리뷰': '해외 로밍 서비스 가입했는데, 현지에서 제대로 작동하지 않았어요.',
#   '감성': '부정',
#   '감성 키워드': '제대로 작동하지 않았어요'},
#  '7': {'리뷰': '지난달 청구서에 이상한 요금이 청구되었어요. 설명도 없이 말이죠.',
#   '감성': '부정',
#   '감성 키워드': '이상한 요금이 청구되었어요, 설명도 없이'},
#  '8': {'리뷰': '첫 번째 전화로 문제를 해결해 주시지 않고 계속 다른 부서로 연결만 시키더군요. 번거롭습니다.',
#   '감성': '부정',
#   '감성 키워드': '문제를 해결해 주시지 않고, 번거롭습니다'},
#  '9': {'리뷰': '고객센터 응대가 너무 불친절해요. 기분 나빴습니다.',
#   '감성': '부정',
#   '감성 키워드': '불친절해요, 기분 나빴습니다'},
#  '10': {'리뷰': '가입한 서비스의 세부 내용을 명확하게 설명받지 못했습니다.',
#   '감성': '부정',
#   '감성 키워드': '명확하게 설명받지 못했습니다'},
#  '11': {'리뷰': '인터넷 사용 중에 자주 끊김 현상이 발생합니다. 안정성이 필요해요.',
#   '감성': '부정',
#   '감성 키워드': '끊김 현상, 안정성이 필요해요'},
#  '12': {'리뷰': '약정 기간이 끝나가는데 계속해서 영업 전화가 오네요. 사생활 침해감을 느낍니다.',
#   '감성': '부정',
#   '감성 키워드': '영업 전화, 사생활 침해감'},
#  '13': {'리뷰': 'AS를 받으려고 했는데, 가까운 서비스 센터가 없어 멀리 가야 해서 불편합니다.',
#   '감성': '부정',
#   '감성 키워드': '가까운 서비스 센터가 없어, 불편합니다'},
#  '14': {'리뷰': '인터넷 속도가 너무 느려요. 계속 끊기고 스트리밍할 때마다 버퍼링이 일어나서 짜증나네요.',
#   '감성': '부정',
#   '감성 키워드': '느려요, 끊기고, 버퍼링'},
#  '15': {'리뷰': '회선 장애가 있었는데, 복구까지 엄청 오래 걸렸어요. 이런 경우가 잦네요.',
#   '감성': '부정',
#   '감성 키워드': '오래 걸렸어요, 이런 경우가 잦네요'},
#  '16': {'리뷰': '고객 센터 전화를 너무 오래 기다려야 해요. 30분 넘게 기다린 후에도 제대로 된 답변을 받지 못했습니다.',
#   '감성': '부정',
#   '감성 키워드': '오래 기다려야 해요, 제대로 된 답변을 받지 못했습니다'},
#  '17': {'리뷰': '지난번에 신청한 부가 서비스가 아직 활성화되지 않았어요. 언제쯤 가능한 건가요?',
#   '감성': '부정',
#   '감성 키워드': '활성화되지 않았어요'},
#  '18': {'리뷰': '인터넷 설치 기사분이 시간 약속도 잘 지키시고 설치도 깔끔하게 해주셨습니다.',
#   '감성': '긍정',
#   '감성 키워드': '시간 약속 잘 지키시고, 설치 깔끔하게'},
#  '19': {'리뷰': '지난 번 고장 신고 후 빠른 기술 지원을 받았습니다. 서비스가 매우 신속했어요.',
#   '감성': '긍정',
#   '감성 키워드': '빠른 기술 지원, 신속했어요'},
#  '20': {'리뷰': '고객센터의 빠른 응대로 제 문제가 즉시 해결되어 매우 만족합니다.',
#   '감성': '긍정',
#   '감성 키워드': '빠른 응대, 즉시 해결되어, 만족합니다'},
#  '21': {'리뷰': '인터넷 설치 기사가 약속 시간에 늦었어요. 전화도 제가 먼저 해야 했습니다.',
#   '감성': '부정',
#   '감성 키워드': '약속 시간에 늦었어요, 전화도 제가'},
#  '22': {'리뷰': '지난 주에 문의 드린 내용에 대한 후속 조치가 전혀 없습니다. 연락 부탁드립니다.',
#   '감성': '부정',
#   '감성 키워드': '후속 조치가 전혀 없습니다'},
#  '23': {'리뷰': '신규 가입 프로모션 혜택이 제대로 적용되지 않았습니다. 확인 부탁드립니다.',
#   '감성': '부정',
#   '감성 키워드': '제대로 적용되지 않았습니다'},
#  '24': {'리뷰': '결제 오류가 있었는데, 해결하는데 너무 오래 걸렸습니다. 불편하네요.',
#   '감성': '부정',
#   '감성 키워드': '오래 걸렸습니다, 불편하네요'},
#  '25': {'리뷰': '모바일 앱 개선 후 훨씬 사용하기 좋아졌어요. 오류도 줄고 속도도 빨라졌습니다.',
#   '감성': '긍정',
#   '감성 키워드': '좋아졌어요, 오류도 줄고, 속도도 빨라졌습니다'},
#  '26': {'리뷰': '최근에 고객센터와 통화했을 때, 상담원이 매우 친절하게 문제를 해결해 주셨어요. 감사합니다.',
#   '감성': '긍정',
#   '감성 키워드': '친절하게, 문제를 해결해 주셨어요'},
#  '27': {'리뷰': '지난번 고객 만족 설문조사 이후 서비스 개선이 눈에 띄게 좋아졌습니다. 계속해서 좋은 서비스 부탁드립니다.',
#   '감성': '긍정',
#   '감성 키워드': '서비스 개선, 좋아졌습니다'},
#  '28': {'리뷰': '휴대폰 교체 프로세스가 매우 편리했습니다. 전반적인 서비스에 만족합니다.',
#   '감성': '긍정',
#   '감성 키워드': '편리했습니다, 만족합니다'},
#  '29': {'리뷰': '요금제 변경 후에 이용하는 데 만족하고 있습니다. 새로운 요금제가 저에게 잘 맞아요.',
#   '감성': '긍정',
#   '감성 키워드': '만족하고 있습니다, 잘 맞아요'}}

# %%
import pandas as pd
pd.DataFrame(response.values())
# Out:
#                                                    리뷰  감성  \
# 0         데이터 사용량 추가 구매가 간편해졌어요. 몇 번의 클릭으로 쉽게 해결되더군요.  긍정
# 1                 휴대폰 보험 클레임 처리가 너무 복잡하고 시간이 많이 걸립니다.  부정
# 2        모바일 앱이 자주 오류를 내요. 로그인이 안 되거나, 갑자기 종료되기도 합니다.  부정
# 3            데이터 속도가 약속된 것보다 훨씬 느립니다. 계약할 때와 너무 다릅니다.  부정
# 4         신규 가입 프로모션이 좋았습니다. 가입 조건도 명확하고 혜택도 만족스럽습니다.  긍정
# 5   요금제 변경 요청했는데 처리가 너무 느리고, 처리 과정에서도 정보가 제대로 전달되지...  부정
# 6                해외 로밍 서비스 가입했는데, 현지에서 제대로 작동하지 않았어요.  부정
# 7                지난달 청구서에 이상한 요금이 청구되었어요. 설명도 없이 말이죠.  부정
# 8   첫 번째 전화로 문제를 해결해 주시지 않고 계속 다른 부서로 연결만 시키더군요. 번...  부정
# 9                        고객센터 응대가 너무 불친절해요. 기분 나빴습니다.  부정
# 10                   가입한 서비스의 세부 내용을 명확하게 설명받지 못했습니다.  부정
# 11              인터넷 사용 중에 자주 끊김 현상이 발생합니다. 안정성이 필요해요.  부정
# 12       약정 기간이 끝나가는데 계속해서 영업 전화가 오네요. 사생활 침해감을 느낍니다.  부정
# 13       AS를 받으려고 했는데, 가까운 서비스 센터가 없어 멀리 가야 해서 불편합니다.  부정
# 14  인터넷 속도가 너무 느려요. 계속 끊기고 스트리밍할 때마다 버퍼링이 일어나서 짜증나네요.  부정
# 15          회선 장애가 있었는데, 복구까지 엄청 오래 걸렸어요. 이런 경우가 잦네요.  부정
# 16  고객 센터 전화를 너무 오래 기다려야 해요. 30분 넘게 기다린 후에도 제대로 된 ...  부정
# 17       지난번에 신청한 부가 서비스가 아직 활성화되지 않았어요. 언제쯤 가능한 건가요?  부정
# 18         인터넷 설치 기사분이 시간 약속도 잘 지키시고 설치도 깔끔하게 해주셨습니다.  긍정
# 19       지난 번 고장 신고 후 빠른 기술 지원을 받았습니다. 서비스가 매우 신속했어요.  긍정
# 20               고객센터의 빠른 응대로 제 문제가 즉시 해결되어 매우 만족합니다.  긍정
# 21         인터넷 설치 기사가 약속 시간에 늦었어요. 전화도 제가 먼저 해야 했습니다.  부정
# 22      지난 주에 문의 드린 내용에 대한 후속 조치가 전혀 없습니다. 연락 부탁드립니다.  부정
# 23          신규 가입 프로모션 혜택이 제대로 적용되지 않았습니다. 확인 부탁드립니다.  부정
# 24             결제 오류가 있었는데, 해결하는데 너무 오래 걸렸습니다. 불편하네요.  부정
# 25       모바일 앱 개선 후 훨씬 사용하기 좋아졌어요. 오류도 줄고 속도도 빨라졌습니다.  긍정
# 26  최근에 고객센터와 통화했을 때, 상담원이 매우 친절하게 문제를 해결해 주셨어요. 감...  긍정
# 27  지난번 고객 만족 설문조사 이후 서비스 개선이 눈에 띄게 좋아졌습니다. 계속해서 좋...  긍정
# 28           휴대폰 교체 프로세스가 매우 편리했습니다. 전반적인 서비스에 만족합니다.  긍정
# 29    요금제 변경 후에 이용하는 데 만족하고 있습니다. 새로운 요금제가 저에게 잘 맞아요.  긍정
#
#                             감성 키워드
# 0                       간편해졌어요, 쉽게
# 1                복잡하고, 시간이 많이 걸립니다
# 2            오류, 로그인이 안 되거나, 종료되기도
# 3                       느립니다, 다릅니다
# 4             좋았습니다, 명확하고, 만족스럽습니다
# 5           느리고, 정보가 제대로 전달되지 않았어요
# 6                    제대로 작동하지 않았어요
# 7           이상한 요금이 청구되었어요, 설명도 없이
# 8           문제를 해결해 주시지 않고, 번거롭습니다
# 9                  불친절해요, 기분 나빴습니다
# 10                 명확하게 설명받지 못했습니다
# 11                끊김 현상, 안정성이 필요해요
# 12                  영업 전화, 사생활 침해감
# 13           가까운 서비스 센터가 없어, 불편합니다
# 14                   느려요, 끊기고, 버퍼링
# 15             오래 걸렸어요, 이런 경우가 잦네요
# 16  오래 기다려야 해요, 제대로 된 답변을 받지 못했습니다
# 17                      활성화되지 않았어요
# 18           시간 약속 잘 지키시고, 설치 깔끔하게
# 19                 빠른 기술 지원, 신속했어요
# 20           빠른 응대, 즉시 해결되어, 만족합니다
# 21             약속 시간에 늦었어요, 전화도 제가
# 22                  후속 조치가 전혀 없습니다
# 23                  제대로 적용되지 않았습니다
# 24                 오래 걸렸습니다, 불편하네요
# 25       좋아졌어요, 오류도 줄고, 속도도 빨라졌습니다
# 26              친절하게, 문제를 해결해 주셨어요
# 27                  서비스 개선, 좋아졌습니다
# 28                   편리했습니다, 만족합니다
# 29                만족하고 있습니다, 잘 맞아요

# %% [markdown]
# # Mini Project 3
# ## tools
# - 필요한 함수를 parameter와 함께 보여줌
#
# ## RapidAPI
# [url](https://rapidapi.com/hub)

# %%
import requests
RapidAPI_KEY = os.environ.get("RAPIDAPI_KEY", "5e2236446emshb04ffd7cef7d164p1f7f37jsnf92bac5a8714") # set juptyer notebook system variable

# %%
def postprocessing_news_data(news_data): 
    snippets = {}
    for item in news_data['items']:
        cur_snippet = "Main Content: "+item["snippet"]+ "\nURL: "+item["newsUrl"]
        if item["hasSubnews"]:
            cur_snippet += "\nSub Content: "
            for sub_item in item["subnews"]:
                cur_snippet += " " + sub_item["snippet"]
        snippets[item["title"]] = cur_snippet
    return snippets

# %%
def call_news_api(category:str, language_location:str):
	assert category in ["entertainment", "world", "business", "health", "science", "sports", "technology"], "category should be one of 'entertainment', 'world', 'business', 'health', 'science', 'sports', 'technology'"
	url = "https://google-news13.p.rapidapi.com/" + category

	assert language_location in ["ko-KR", "en-US"], "language_location should be one of 'ko-KR', 'en-US'"
	querystring = {"lr":language_location}

	headers = {
		"X-RapidAPI-Key": RapidAPI_KEY,
		"X-RapidAPI-Host": "google-news13.p.rapidapi.com"
	}

	response = requests.get(url, headers=headers, params=querystring)
	# return response.json()
	output = postprocessing_news_data(response.json())
	return output

# %% [markdown]
# ## 후처리 테스트 시작

# %%
news_output = call_news_api("technology", "ko-KR")
len(news_output['items'])
# Out:
# 61

# %%
news_output['items'][0].keys()
# Out:
# dict_keys(['title', 'snippet', 'publisher', 'timestamp', 'newsUrl', 'images', 'hasSubnews', 'subnews'])

# %%
sample_data = news_output['items'][0]
sample_data
# Out:
# {'title': '[와글와글] "PC방인가요?" 카페 탁자에 모니터가 웬 말?',
#  'snippet': '한 프랜차이즈 카페에서 촬영된 사진이 온라인을 떠들썩하게 만들었는데요. 탁자 두 곳에 모니터와 노트북이 올라가 있고요. 키보드와 멀티탭도 놓여있습니다.',
#  'publisher': 'MBC 뉴스',
#  'timestamp': '1713735487000',
#  'newsUrl': 'https://imnews.imbc.com/replay/2024/nwtoday/article/6591328_36523.html',
#  'images': {'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNWxZa2RmTVVKck5ETmhPRVE0VFJDZkF4ampCU2dLTWdhQklZS3ByUVE=-w280-h168-p-df-rw',
#   'thumbnailProxied': 'https://i.zedtranslate.com/newsimage/CC8iK0NnNWxZa2RmTVVKck5ETmhPRVE0VFJDZkF4ampCU2dLTWdhQklZS3ByUVE'},
#  'hasSubnews': True,
#  'subnews': [{'title': '"3000원 커피 주문 후, 3시간 앉아 있다 쫓겨났어요"',
#    'snippet': '한 프랜차이즈 카페에서 오래 앉아있었다는 이유로 쫓겨났다는 사연을 두고 누리꾼들 간 또다시 카페 이용 시간에 관한 갑론을박이 벌어졌다.',
#    'publisher': '머니투데이',
#    'timestamp': '1713838063000',
#    'newsUrl': 'https://news.mt.co.kr/mtview.php?no=2024042310513156974',
#    'images': {'thumbnail': 'https://news.google.com/api/attachments/CC8iJ0NnNUZTbk5wTFd0UExYUm1ja1pLVFJDZkF4ampCU2dLTWdNaFl3Zw=-w280-h168-p-df-rw',
#     'thumbnailProxied': 'https://i.zedtranslate.com/newsimage/CC8iJ0NnNUZTbk5wTFd0UExYUm1ja1pLVFJDZkF4ampCU2dLTWdNaFl3Zw'}},
#   {'title': '“타인 피해” vs “차별 조장” 엇갈린 반응',
#    'snippet': "22일 오후 2시쯤 인천 서구 심곡동 한 카페 앞.카페 출입구에는 '노 스터디존(No Study Zone)'이라고 적힌 안내판이 놓여 있었다.업주 박모(53·여)씨는 “10대와 20대 ...",
#    'publisher': '인천일보',
#    'timestamp': '1713782340000',
#    'newsUrl': 'https://www.incheonilbo.com/news/articleView.html?idxno=1246123',
#    'images': {'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNUdZMjFEVkVKdVFXVXdYekJEVFJEQ0FSaURBaWdCTWdhdGRKS3VNUVk=-w280-h168-p-df-rw',
#     'thumbnailProxied': 'https://i.zedtranslate.com/newsimage/CC8iK0NnNUdZMjFEVkVKdVFXVXdYekJEVFJEQ0FSaURBaWdCTWdhdGRKS3VNUVk'}},
#   {'title': '테이블 2개 붙이고 대형 모니터 차린 카페 손님 논란 [잇슈 키워드]',
#    'snippet': "마지막 키워드는, '모니터'입니다. 요즘 카페에서 공부하거나 일하는 사람들 쉽게 볼 수 있지만, 이들을 보...",
#    'publisher': 'KBS뉴스',
#    'timestamp': '1713738540000',
#    'newsUrl': 'https://news.kbs.co.kr/news/pc/view/view.do?ncd=7945085',
#    'images': {'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNXBaRmRRTWxkeGNFOXRlRmg1VFJDb0FSaXNBaWdCTWdZQlVvYXNMUWM=-w280-h168-p-df-rw',
#     'thumbnailProxied': 'https://i.zedtranslate.com/newsimage/CC8iK0NnNXBaRmRRTWxkeGNFOXRlRmg1VFJDb0FSaXNBaWdCTWdZQlVvYXNMUWM'}},
#   {'title': '카페에 대형모니터 가져온 \'카공족\' 논란…"우리도 할 말 있다" [일상톡톡 플러스]',
#    'snippet': "한눈에 보는 오늘 : 사회 - 뉴스 : “메뉴가격 4100원일 때 테이블당 체류시간 1시간42분 넘지 않아야 손익분기점 넘길 수 있어” 최근 카페 좋은 자리는 '카공족'이 다 ...",
#    'publisher': '네이트 뉴스',
#    'timestamp': '1713610920000',
#    'newsUrl': 'https://news.nate.com/view/20240420n10124',
#    'images': {'thumbnail': 'https://news.google.com/api/attachments/CC8iK0NnNVFWR1IzTmpJdFkxSXROV3R5VFJDWEF4amlCQ2dLTWdhMVFZeTFIQWs=-w280-h168-p-df-rw',
#     'thumbnailProxied': 'https://i.zedtranslate.com/newsimage/CC8iK0NnNVFWR1IzTmpJdFkxSXROV3R5VFJDWEF4amlCQ2dLTWdhMVFZeTFIQWs'}},
#   {'title': '“내 눈을 의심함”…스벅에 모니터 들고 온 손님, 괜찮나요?',
#    'snippet': '커피전문점에서 노트북에 컴퓨터 모니터까지 들고 와 이를 설치한 후 태연히 작업을 하는 손님 사진이 공개되자 온라인상에서 논란이 일고 있다.',
#    'publisher': '헤럴드경제',
#    'timestamp': '1713524449000',
#    'newsUrl': 'https://biz.heraldcorp.com/view.php?ud=20240419050637',
#    'images': {'thumbnail': 'https://news.google.com/api/attachments/CC8iL0NnNVlaamhDVVVaUWJUYzRSR2h0VFJEVEF4aUhCU2dLTWdrQlVZWmtMcWRVU2dJ=-w280-h168-p-df-rw',
#     'thumbnailProxied': 'https://i.zedtranslate.com/newsimage/CC8iL0NnNVlaamhDVVVaUWJUYzRSR2h0VFJEVEF4aUhCU2dLTWdrQlVZWmtMcWRVU2dJ'}}]}

# %%
cur_prompt = 'Main Content: ' + sample_data['snippet'] + '\nURL: ' + sample_data['newsUrl']

# %%
cur_prompt += '\nSub Content: '
if sample_data['subnews']:
    for sub_item in sample_data['subnews']:
        cur_prompt += sub_item['snippet'] + ' '

# %%
cur_prompt
# Out:
# "Main Content: 한 프랜차이즈 카페에서 촬영된 사진이 온라인을 떠들썩하게 만들었는데요. 탁자 두 곳에 모니터와 노트북이 올라가 있고요. 키보드와 멀티탭도 놓여있습니다.\nURL: https://imnews.imbc.com/replay/2024/nwtoday/article/6591328_36523.html\nSub Content: 한 프랜차이즈 카페에서 오래 앉아있었다는 이유로 쫓겨났다는 사연을 두고 누리꾼들 간 또다시 카페 이용 시간에 관한 갑론을박이 벌어졌다. 22일 오후 2시쯤 인천 서구 심곡동 한 카페 앞.카페 출입구에는 '노 스터디존(No Study Zone)'이라고 적힌 안내판이 놓여 있었다.업주 박모(53·여)씨는 “10대와 20대 ... 마지막 키워드는, '모니터'입니다. 요즘 카페에서 공부하거나 일하는 사람들 쉽게 볼 수 있지만, 이들을 보... 한눈에 보는 오늘 : 사회 - 뉴스 : “메뉴가격 4100원일 때 테이블당 체류시간 1시간42분 넘지 않아야 손익분기점 넘길 수 있어” 최근 카페 좋은 자리는 '카공족'이 다 ... 커피전문점에서 노트북에 컴퓨터 모니터까지 들고 와 이를 설치한 후 태연히 작업을 하는 손님 사진이 공개되자 온라인상에서 논란이 일고 있다. "

# %% [markdown]
# ## 정상 함수 시작

# %%
tools = [{
    "type" : "function",
    "function": {
            "name": "call_news_api",
            "description": "call news_api with the given category",  # function의 description을 보고 실행할 함수를 결정
            "parameters": {
                "type": "object",
                "properties": {
                    "category": {
                        "type": "string",
                        "description": "news cateogry to get the news. list of categories: entertainment, world, business, health, science, sports, technology"
                    },
                    "language_location": {
                        "type": "string",
                        "description": "language and location of the news. default is 'ko-KR'. list of language and location: 'en-US', 'ko-KR'"
                    }
                },
                "required": ["category", "language_location"],
            },
    } 
}]

# %%
def run_gpt(model:str, messages:list, max_token:int=150, temperature:float=0.7, is_json:bool=False, seed:int=None, tools:list=None, tool_choice:str=None, stream:bool=False):

    response = client.chat.completions.create(
        model=model,
        messages=messages,
        max_tokens=max_token,
        temperature=temperature,
        response_format = {'type' : 'json_object'} if is_json else {'type' : 'text'},
        seed=seed,
        tools=tools,
        tool_choice="auto" if tools else tool_choice,
        stream=stream
    )
    
    return response

# %%
user_interested_category = "AI, 대규모 언어 모델"# 관심 주제 설정
language = "한국어" # 언어 설정
system_message = "너는 사람들의 관심사에 맞는 뉴스 주제를 선택해서 RapidAPI를 통해서 기사를 찾아주는 비서야." # RapidAPI를 통해 관심사에 맞는 뉴스 찾는 역할 부여
user_message = f"""
나의 관심 주제는 {user_interested_category}이야.
나는 {language}로 된 뉴스를 원해.

너는 다음 단계에 따라서 뉴스 요약본을 생성해줘.
1. 나의 관심 주제를 보고 이를 [entertainment, world, business, health, science, sports, technology] 중 하나로 변환해줘.
2. 변환된 뉴스 카테고리와 내가 설정한 언어를 기반으로 RapidAPI를 사용해서 뉴스 데이터를 가져와줘.
""" # 관심 주제를 뉴스 카테고리로 변환 요청 및 해당 언어의 뉴스 요청

model = "gpt-4-turbo"
max_token = 3000
messages = [
    {"role": "system", "content": system_message},
    {"role": "user", "content": user_message}
]

# %%
max_token = 150
temperature = 0.7
is_json = False
seed = 100
stream = False
response = run_gpt(model, messages, max_token=max_token, temperature=temperature, 
                   is_json=is_json, seed=seed, tools=tools, tool_choice="auto", stream=stream) # run_gpt 실행

# %%
response.choices[0].message
# Out:
# ChatCompletionMessage(content=None, role='assistant', function_call=None, tool_calls=[ChatCompletionMessageToolCall(id='call_dZ3XdkXZOSp7nl4kWSzCE0rJ', function=Function(arguments='{"category":"technology","language_location":"ko-KR"}', name='call_news_api'), type='function')])

# %%
# 실제로 함수를 실행하기 위해서 response의 Function object를 message의 content에 추가하고 실행
assistant_message = response.choices[0].message
assistant_message.content = str(assistant_message.tool_calls[0].function) 
messages.append({"role": assistant_message.role, "content": assistant_message.content})

# %%
messages
# Out:
# [{'role': 'system',
#   'content': '너는 사람들의 관심사에 맞는 뉴스 주제를 선택해서 RapidAPI를 통해서 기사를 찾아주는 비서야.'},
#  {'role': 'user',
#   'content': '\n나의 관심 주제는 AI, 대규모 언어 모델이야.\n나는 한국어로 된 뉴스를 원해.\n\n너는 다음 단계에 따라서 뉴스 요약본을 생성해줘.\n1. 나의 관심 주제를 보고 이를 [entertainment, world, business, health, science, sports, technology] 중 하나로 변환해줘.\n2. 변환된 뉴스 카테고리와 내가 설정한 언어를 기반으로 RapidAPI를 사용해서 뉴스 데이터를 가져와줘.\n'},
#  {'role': 'assistant',
#   'content': 'Function(arguments=\'{"category":"technology","language_location":"ko-KR"}\', name=\'call_news_api\')'}]

# %%
# selected_topic = json.loads(response.message.tool_calls[0].function.arguments)["category"]

# %%
def execute_function_call(message):
    if message.tool_calls[0].function.name == "call_news_api":
        cat = json.loads(message.tool_calls[0].function.arguments)["category"]
        lang = json.loads(message.tool_calls[0].function.arguments)["language_location"]
        results = call_news_api(cat, lang)
    else:
        results = f"Error: function {message.tool_calls[0].function.name} does not exist"
    return results

# %%
# save the result of function into "tool message"
if assistant_message.tool_calls:
    results = execute_function_call(assistant_message)
    messages.append({"role": "tool", "tool_call_id": assistant_message.tool_calls[0].id, "name": assistant_message.tool_calls[0].function.name, "content": results})

# %%
messages
# Out:
# [{'role': 'system',
#   'content': '너는 사람들의 관심사에 맞는 뉴스 주제를 선택해서 RapidAPI를 통해서 기사를 찾아주는 비서야.'},
#  {'role': 'user',
#   'content': '\n나의 관심 주제는 AI, 대규모 언어 모델이야.\n나는 한국어로 된 뉴스를 원해.\n\n너는 다음 단계에 따라서 뉴스 요약본을 생성해줘.\n1. 나의 관심 주제를 보고 이를 [entertainment, world, business, health, science, sports, technology] 중 하나로 변환해줘.\n2. 변환된 뉴스 카테고리와 내가 설정한 언어를 기반으로 RapidAPI를 사용해서 뉴스 데이터를 가져와줘.\n'},
#  {'role': 'assistant',
#   'content': 'Function(arguments=\'{"category":"technology","language_location":"ko-KR"}\', name=\'call_news_api\')'},
#  {'role': 'tool',
#   'tool_call_id': 'call_dZ3XdkXZOSp7nl4kWSzCE0rJ',
#   'name': 'call_news_api',
#   'content': {'[와글와글] "PC방인가요?" 카페 탁자에 모니터가 웬 말?': "Main Content: 한 프랜차이즈 카페에서 촬영된 사진이 온라인을 떠들썩하게 만들었는데요. 탁자 두 곳에 모니터와 노트북이 올라가 있고요. 키보드와 멀티탭도 놓여있습니다.\nURL: https://imnews.imbc.com/replay/2024/nwtoday/article/6591328_36523.html\nSub Content:  한 프랜차이즈 카페에서 오래 앉아있었다는 이유로 쫓겨났다는 사연을 두고 누리꾼들 간 또다시 카페 이용 시간에 관한 갑론을박이 벌어졌다. 22일 오후 2시쯤 인천 서구 심곡동 한 카페 앞.카페 출입구에는 '노 스터디존(No Study Zone)'이라고 적힌 안내판이 놓여 있었다.업주 박모(53·여)씨는 “10대와 20대 ... 마지막 키워드는, '모니터'입니다. 요즘 카페에서 공부하거나 일하는 사람들 쉽게 볼 수 있지만, 이들을 보... 한눈에 보는 오늘 : 사회 - 뉴스 : “메뉴가격 4100원일 때 테이블당 체류시간 1시간42분 넘지 않아야 손익분기점 넘길 수 있어” 최근 카페 좋은 자리는 '카공족'이 다 ... 커피전문점에서 노트북에 컴퓨터 모니터까지 들고 와 이를 설치한 후 태연히 작업을 하는 손님 사진이 공개되자 온라인상에서 논란이 일고 있다.",
#    '테슬라, LG엔솔에 전극 6조 주문…"배터리 자체 생산"': "Main Content: 테슬라, LG엔솔에 전극 6조 주문…배터리 자체 생산, 경제.\nURL: https://www.hankyung.com/article/2024042266085\nSub Content:  앵커> 미국 전기차 업체 테슬라가 LG에너지솔루션에 6조원 규모의 전극을 주문한 것으로 확인됐습니다. 완제품인 배터리셀이 아닌 원재료를 가공한 전극을 요청한 ... LG에너지솔루션이 기술리더십을 바탕으로 차별적 고객가치 실현에 나선다. 출범 이후 지속적으로 연구개발(R&D) 비용을 확대하며 차세대 배터리 분야에서 양산과 ... 로보택시 공개를 앞둔 테슬라가 LG에너지솔루션의 배터리를 대거 사들이고 있다. 부진한 업황 타개에 새로운 모멘텀이 될 수 있을지 관심이 쏠린다. [이코리아] 최근 성과급에 대한 불만으로 서울 여의도 일대에서 트럭시위를 벌였던 LG에너지솔루션 직원들의 작년 평균 보수가 1억2300만 원, 임원은 8억5500만 원으로 ... LG에너지솔루션의 '김동명 체제'가 난기류를 극복할 수 있을까. 전기차 전방 수요 증가세 둔화, 중국 배터리 기업의 약진 등 변수에 LG에너지솔루션이 고전하는 모양새 ...",
#    "실적 불안에 삼성전자 SK하이닉스 주가 흔들, 증시 'AI 파티' 이대로 끝나나": 'Main Content: [비즈니스포스트] 올해 국내외 증시를 이끌어온 반도체주에 대한 투자심리가 흔들리고 있다.삼성전자, SK하이닉스 등 국내 반도체주가 1분기 어닝시즌 \'실적 피크\' ..\nURL: https://www.businesspost.co.kr/BP?command=article_view&num=349830\nSub Content:  삼성전자와 더불어 국내 증시에서 대표적인 반도체 대장주로 꼽히는 SK하이닉스의 주가 흐름이 심상치 않다. 지난 12일 19만원 선까지 올라서며 고점을 기록한 뒤 큰 ... 오늘의 포인트반도체 대장주 삼성전자와 SK하이닉스가 나란히 약세다. 미국 증시에서 엔비디아가 10% 하락하는 등 반도체주 주가가 동반 급락한 영향이다. 지난주 뉴욕증시의 주요 기술주인 매그니피센트(Magnificent 7, M7) 종목이 급락한 가운데 월가에서 이 종목들에 대한 여러 평가가 나오고 있다. 거래량 석 달 평균치 13일 연속 하회 다음 주 빅테크 실적 주시, 지출 초점 "아직 AI 연산 수요 GPU 공급 압도". 이 기사는 4월 17일 오후 3시37분 \'해외 주식 투자의 ... 최근 우리 주식시장, \'강달러\'에 맥 못 춰 美 금리 인하 지연·중동 위기…위험자산 ...',
#    '에코프로이노 김윤태 “내년 2분기까지 전기차 반등 못해, 배터리 소재 생산 20% 감축”': 'Main Content: [비즈니스포스트] 김윤태 에코프로이노베이션 사장이 전기차 시장 둔화에 따라 전기차 배터리 핵심 소재 생산량을 20%까지 감축할 것이라고 밝혔다.\nURL: https://www.businesspost.co.kr/BP?command=article_view&num=349847',
#    '한국 스마트폰 판매가 세계서 제일 높아, 조사기관 "2029년까지 1위 유지"': 'Main Content: [비즈니스포스트] 한국이 2029년까지 전 세계에서 스마트폰이 가장 비싸게 팔리는 나라가 될 것이라는 전망이 나왔다.22일 시장조사업체 테크인사이트의 보고서에 ...\nURL: https://www.businesspost.co.kr/BP?command=article_view&num=349863\nSub Content:  스마트폰 가격 비싸다 했더니” 이 정도일 줄은 몰랐다. 한국이 전세계에서 스마트폰 가격이 가장 비싼 국가가 됐다. 젊은층의 비싼 아이폰 선호도가 큰 영향을 미쳤다. 한국이 앞으로 5년 동안 전 세계에서 휴대전화가 가장 비싼 나라 1위를 유지할 것이란 전망이 나왔습니다.... 한국이 전 세계에서 스마트폰이 가장 비싸게 팔리는 나라 1위를 유지할 것이라는 전망... 산업 > 산업일반 뉴스: 세계에서 한국의 스마트폰 평균 판매 가격이 가장 비싸다는 조사 결과가 나왔다. 시장조사업체 스트래티지 애널리틱스(SA)에 따... 테크인사이트 조사 결과 2위·3위는 일본과 영국 “2029년까지 가장 비쌀 것”, 한국이 전 세계에서 스마트폰이 가장 비싸게 팔리는 나라인 것으로 조사됐다.',
#    '안드로이드 15에 추가될 신기능 10가지': 'Main Content: 구글 모바일 운영체제 안드로이드의 최신 버전 출시가 멀지 않았다. 새로운 안드로이드 15는 5월에 열리는 구글 I/O 행사에서 공개된 후 올해.\nURL: https://www.itworld.co.kr/news/334436',
#    '[매경 CEO 특강] 비트코인은 디지털 金 … 가치 더 커질 것': "Main Content: 비트코인은 비효율적이고 불합리적인 기존 금융거래 시스템에서 벗어나기 위해 개발됐습니다. 가치 저장 수단인 비트코인은 현대 금융체제에서 중요성이 커진다고 생각 ...\nURL: https://www.mk.co.kr/news/society/10996809\nSub Content:  비트코인은 금융의 패러다임을 어디까지 혁신할 수 있을까. 비트코인을 중심으로 국내외 가상자산의 미래에 대한 통찰력을 제시하는 '비트코인 서울 2024'가 오는 5월 ... 미국과 홍콩의 ETF 승인의 의미…비트코인을 바라보는 눈이 달라졌다 ▷김광석> 비트코인이 이제 EFT 승인이 됐고 그러면 자금이 그쪽으로 간접 투자 방식으로 쏠린다 ... 블록체人⑯ 정석문 프레스토 리서치센터장 5년 묻어둘 자산 정답은 비트코인 코인도 장기 투자가 답 알트코인 변동성 커 위험 비트코인·이더리움 투자만 권장 비트코인 ... [탐사보도 뉴스프리즘] 비트코인 '횡재' 엘살바도르, 마지막까지 웃을까 [오프닝: 이광빈 기자] 안녕하십니까 이광빈입니다. 우리 사회의 문제점을 진단하고, ... 비트코인 열풍과 나의 아홉번째 이야기 | 재래 통화의 근본적인 문제는 그것이 작동하게 하는데 필요한 모든 신뢰입니다. 중앙은행은 통화 가치를 떨어뜨리지 않도록 ...",
#    '자율주행차 최고 기술력, 테슬라가 아니네...‘이 회사’가 앞질렀다': 'Main Content: 독일의 자동차 회사 메르세데스 벤츠가 미국에서 처음으로 자율주행 3단계 차량의 상용화에 성공했다고 21일(현지시간) 포천이 보도했다.\nURL: https://www.mk.co.kr/news/business/10996442',
#    '[오늘의 스팀] 에픽 강제, 데드 아일랜드 2 평가 ↓': "Main Content: 정확히 1년 전, PC에서는 에픽게임즈 스토어 독점으로 출시됐던 '데드 아일랜드 2(Dead Island 2)'가 에픽 기간독점을 끝내고 22일 스팀에도 출시됐다.\nURL: https://www.gamemeca.com/view.php?gid=1748226",
#    "아이폰16에 '온디바이스AI 온리' 적용 예상, 삼성전자 SK하이닉스 저전력 D램 수혜 보나": "Main Content: [비즈니스포스트] 애플이 오는 가을에 출시할 아이폰16에 외부 클라우드 서버와 연결 없이 순수하게 기기 내에서 인공지능(AI) 기능을 제공하는 '온 디바이스 AI 온리( ...\nURL: https://www.businesspost.co.kr/BP?command=article_view&num=349819",
#    '“반도체 잔치 다 끝났나”...엔비디아 폭락에 삼성·SK하이닉스 ‘초긴장’': 'Main Content: 올초부터 석달간 98% 오른 엔비디아, 가격부담과 업황우려에 하루만에 급락 매크로 환경 급변에 테크주 차익실현 한국 반도체주도 올해 순이익 전망에 비해 선반영된 ...\nURL: https://www.mk.co.kr/news/stock/10996050',
#    '비트코인 9600만 원대로 올라, 가상화폐 분석가 13억 원 전망 전해져': 'Main Content: [비즈니스포스트]비트코인 시세가 9600만 원대에서 오르고 있다.비트코인이 비트코인 현물 상장지수펀드(ETF)에 유입되는 기관 투자자의 자금에 힘입어 100만 달러(약 ...\nURL: https://www.businesspost.co.kr/BP?command=article_view&num=349844',
#    'AI폰 순풍 올라탄 삼성전자 스마트폰, 세계 1위 수성 복병은 카메라': 'Main Content: 삼성전자가 인공지능(AI) 기능을 앞세운 갤럭시S24로 흥행가도를 달려가고 있지만, 카메라 성능을 두고 논란이 생기고 있다. <그래픽 비즈니스포스트>[비즈니스포스트] ...\nURL: https://www.businesspost.co.kr/BP?command=article_view&num=349700',
#    '리플 반등: XRP 가격이 중요한 전환점을 맞았다 - 다음 단계는?': 'Main Content: 리플의 0.43달러 반등은 시장 심리와 리플의 진행 상황에 달려 있습니다. 지속적인 모멘텀을 위해서는 지속적인 모니터링이 중요합니다.\nURL: https://kr.beincrypto.com/base-news/54353/',
#    '라이카 감성에 흠뻑, 라이츠폰3': "Main Content: 라이카에서 만든 세 번째 스마트폰 '라이츠폰3'가 출시됐습니다. 2021년 첫 폰을 선보인 후 꾸준히 업그레이드하고 있습니다. 라이카에서 만든 스마트폰인만큼 카메라 ...\nURL: https://the-edit.co.kr/66634",
#    '美 압박에도 2조 순익... K배터리 충격 빠뜨린 中 CATL의 독주 비결': 'Main Content: 지난 15일 중국 최대 배터리 기업 CATL이 1분기 실적을 발표하자, 선전 증시에 상장된 CATL 주가는 하루 만에 4.6% 급등했다. 한국 배터리 업계는 충격을 받았다.\nURL: https://www.chosun.com/economy/industry-company/2024/04/23/EZ7DFFSFDNBLBGT6ANSF3SDAY4/',
#    '11년 만에, 세븐 데이즈 투 다이 6월 정식 출시': 'Main Content: 세븐 데이즈 투 다이가 앞서 해보기 11년 만에 정식 출시를 예고했다. 세븐 데이즈 투 다이는 2013년부터 현재까지 무려 11년 동안 스팀에서 앞서 해보기 중인 좀비 ...\nURL: https://www.gamemeca.com/view.php?gid=1748193',
#    '[주간스팀신작] 레포데 풍 협동 슈팅게임 등 3종': 'Main Content: 스팀에는 매일 수많은 게임들이 출시됩니다. 너무 많아서 진흙 속에 묻힌 진주를 찾아내기 어려울 정도죠. [주간스팀신작] 코너에서는 지난 한 주 동안 출시된 게임 중 ...\nURL: https://www.gamemeca.com/view.php?gid=1748189',
#    'AI전투기가 온다…美 “개발 속도 예상보다 빨라”': 'Main Content: 인공지능(AI)이 조종하는 F-16 개조 전투기(X-62A)와 인간 조종사가 모는 F-16이 최대 시속 1931km로 주변을 비행한다. 그러다 AI의 전투기가 전술 기동을 하며 유인 ...\nURL: https://www.mk.co.kr/news/world/10996885',
#    "애플 '파인우븐 케이스', 결국 생산 중단…신소재 시도 예정": 'Main Content: [디지털투데이 AI리포터] 애플이 파인우븐 케이스 및 애플워치 밴드의 생산을 중단했다고 21일(현지시간) 모바일 매체 폰아레나가 IT팁스터 코수타미(Kosutami)를 인용 ...\nURL: https://www.digitaltoday.co.kr/news/articleView.html?idxno=514732',
#    '“가상자산 업체 VMS 불법 다단계 코인 사기에 속았다”': 'Main Content: 한인 가상자산(암호화폐) 투자업체 전직 이사와 투자자들이 사기피해를 주장하고 나섰다. 22일 LA한인타운에서 가상자산 업체 VMS USA(Vehicle Mining System...\nURL: https://news.koreadaily.com/2024/04/22/society/generalsociety/20240422205735607.html',
#    "'지상전 최강자'의 굴욕…자폭드론 막으려 그물 덮는 탱크들": "Main Content: (서울=연합뉴스) 황철환 기자 = '지상전 최강자'로 군림하던 전차의 위상이 '드론(무인기) 전쟁'의 시대가 열리면서 곤두박질친 채 고전을 면치 못하고 있다.\nURL: https://www.yna.co.kr/view/AKR20240421037800009",
#    "차세대 리튬 배터리 상용화 임박, 전기차 캐즘 '보릿고개' 탈피 열쇠로 주목": 'Main Content: [비즈니스포스트] 전기차에 가장 광범위하게 활용되는 리튬이온 배터리에서 구조만 일부 바꿔 성능을 개선한 차세대 배터리들의 상용화 가능성이 커지고 있다.\nURL: https://www.businesspost.co.kr/BP?command=article_view&num=349696',
#    "MS, 사진 한장으로 말하고 노래하는 영상 만드는 '바사-1' 공개": 'Main Content: 바사-1 (사진=유튜브)마이크로소프트(MS)가 스틸 사진 한장으로 사람들이 말하고, 몸짓을 하고, 움직이는 실감나는 동영상을 생성할 수 있는 새로운 인공지능(AI) ...\nURL: https://www.aitimes.com/news/articleView.html?idxno=158962',
#    "'아이폰16' 시리즈 이렇게 나온다.. 새로운 케이스 이미지 유출": 'Main Content: 출처: 소니 딕슨. 애플이 올 가을 출시할 차기 아이폰16 시리즈의 후면 디자인을 엿볼 수 있는 새로운 케이스 이미지가 유출됐다.\nURL: https://kbench.com/?q=node/255211',
#    'LG전자 연구 및 전문위원 26명 신규 선발, 조주완 "미래 경쟁력 확보에 앞장"': 'Main Content: [비즈니스포스트] LG전자가 임원급에 맞먹는 처우와 보상을 받는 연구위원 및 전문위원 26명을 새로 선발했다.LG전자는 연구개발(R&D), 디자인, 품질, 정보기술(IT..\nURL: https://www.businesspost.co.kr/BP?command=article_view&num=349708',
#    '오늘은 넷플, 내일은 디플...늘어나는 美 ‘OTT 유목민’': "Main Content: 온라인 동영상 서비스(OTT)들이 각축전을 벌이면서 미국 내에서 구독과 해지를 반복하며 여러 OTT를 번갈아 이용하는 'OTT 유목민'이 늘고 있다고 20일(현지시간) 뉴욕 ...\nURL: https://www.mk.co.kr/news/world/10996443",
#    '“당신은 노숙자가 될 것입니다”....LA의 인공지능 실험': 'Main Content: 경기 둔화 조짐에 미국 캘리포니아에 노숙자가 넘쳐나자, 인공지능(AI)를 활용해 이를 방지하려는 움직임이 일고 있다. 로스앤젤레스 카운티는 인공지능(AI)을 활용해 ...\nURL: https://www.mk.co.kr/news/it/10995809',
#    '삼성전자, 디스플레이 이슈 ‘갤럭시S21·S22’ 디스플레이 무상 교체': 'Main Content: 출처:타룬 바츠 X. 삼성전자가 디스플레이에서 녹색 선이 발생하는 일부 모델에 대해 디스플레이를 무상으로 교체해줄 방침이라고 샘모바일 등 외신이 21일(현지시간) ...\nURL: https://kbench.com/?q=node/255176',
#    '비트코인, 반감기 당일 수수료 수익 급증...이더리움 대비 24배 ↑': 'Main Content: 비트코인의 네 번째 반감기가 진행된 20일 비트코인이 이더리움보다 24배 많은 수수료 수익을 창출한 것으로 확인됐다. 21일(현지시간) 코인텔레그래프는 크립토피 ...\nURL: https://www.tokenpost.kr/article-174657',
#    'TSMC 독주 굳어진다... “2030년 AI칩 매출만 63조, 인텔 파운드리 3배”': 'Main Content: 2030년까지 대만 TSMC의 인공지능(AI) 파운드리(반도체 위탁 생산) 매출 규모가 인텔 파운드리 총 외부 수주액의 3배가 넘을 것이라는 분석이 나왔다.\nURL: https://www.chosun.com/economy/tech_it/2024/04/22/A3E75S6VNNEMHBTFTSZR2IBYQU/',
#    '인텔 1.8나노 파운드리 수주에 정부 도움 받는다, 미국 군사용 반도체 생산': 'Main Content: [비즈니스포스트] 인텔이 1.8나노(18A) 미세공정으로 군사용 반도체 위탁생산을 담당하는 등 미국 정부의 전폭적 지원을 받아 기술 상용화에 속도를 내고 있다.\nURL: https://www.businesspost.co.kr/BP?command=article_view&num=349908',
#    '시바이누(Shiba Inu) 고래지표 이상신호 및 1000억 SHIB 판매 추측': 'Main Content: 놀라운 일이 벌어지고 있는데, 시바이누(SHIB)는 고래 지표에서 상당한 이상신호를 보이고 있다. 주요 거래량이 급증하면서 거래량은 급락하여 암호화폐 시장 전반에 ...\nURL: http://www.tokenpost.kr/article-174745',
#    '삼성SDI, 세계 전기차 석학들에 ‘전고체 배터리’ 선보인다 - 조선비즈': "Main Content: 삼성SDI(006400)가 23일부터 나흘간 서울 강남구 코엑스에서 열리는 '제27회 세계전기자동차 학술대회 및 전시회(EVS37)'에 참가해 미래 전기차용 배터리 기술을 ...\nURL: https://biz.chosun.com/industry/company/2024/04/23/PS55K5UIFVANHMFSTGU6EQ4HC4/",
#    "中 14억 인구 '무서운 실험실'의 역습…전세계 '공포'": 'Main Content: 中 14억 인구 무서운 실험실의 역습…전세계 공포, AI·로봇·자율주행…실리콘밸리 위협하는 테크 굴기 중국판 챗GPT 이용자 2억명…오픈AI와 격차 고작 1년 우한 자율주행 ...\nURL: https://www.hankyung.com/article/2024042159451',
#    '현대차 美 조지아 공장, 태양광으로 돌린다': 'Main Content: 현대차 美 조지아 공장, 태양광으로 돌린다 현대차그룹이 미국 조지아주에 건설중인 전기차 공장을 태양광 에너지를 이용해 가동한다. 현대차그룹은 스페인 재생에너지 ...\nURL: https://www.chosun.com/economy/auto/2024/04/22/ZZQPLAZZQJGWXGGZH35G6AZILU/',
#    '블랙록, "ETF가 살 길이다" ...뮤추얼펀드를 ETF로 전환(ft. 비트코인 ETF)': 'Main Content: 블랙록이 간접투자의 대명사 뮤추얼펀드를 상장지수펀드(ETF)로 전환하는 계획을 발표했다. 블랙록은 비트코인 투자 수단으로 현물 ETF를 만들어 월가에서 선풍적인 ...\nURL: https://www.blockmedia.co.kr/?p=510841',
#    '홍콩 빅토리증권, 비트코인 이더리움 ETF 수수료 공개--"미국 대비 경쟁력 있어"': 'Main Content: 홍콩의 빅토리 증권(Victory Securities)이 최근 비트코인(BTC)과 이더리움(ETH) 현물 ETF 상품 승인 이후, 투자자에게 적용될 예정인 수수료를 공개했다.\nURL: https://www.blockmedia.co.kr/?p=510669',
#    '삼성전자, 업계 최초 ‘9세대 V낸드’ 양산… “데이터 속도 33%↑ 소비전력 10%↓”': "Main Content: 삼성전자가 업계 최초로 '9세대 V(수직)낸드' 양산에 돌입했다. 2022년 11월 8세대 V낸드를 양산하기 시작한지 1년 5개월만이다. 인공지능(AI) 훈련 및 추론 분야가 ...\nURL: https://www.chosun.com/economy/tech_it/2024/04/23/DO2VXNGGDRHY5JABUWAL3OXL3M/",
#    '비트코인 승부사 마이클 세일러, 하루에 8조원을 잃은 적도 있다': 'Main Content: 마이크로스트래티지 창업자 마이클 세일러가 비트코인 투자로 1년만에 30억 달러(4.1조 원)를 벌었다고 20일(현지 시간) 포춘 크립토가 보도했다. 세일러는 승부사다.\nURL: https://www.blockmedia.co.kr/?p=510521',
#    '카이스트 출신 과학자가 도축장 돌며 짐승 피 받아온 이유 [BreakFirst]': 'Main Content: 3초의 정적. 여성 헬스케어 기업 이너시아의 김효이 대표(26)가 창업하겠다고 주변에 말했을 때 마주한 반응입니다. 정적 뒤에는 “왜 굳이?”라는 질문도 따랐습니다.\nURL: https://www.donga.com/news/Economy/article/all/20240422/124587377/1',
#    '일할 때 모니터로부터 내 눈을 보호하는 안경': 'Main Content: 일할 때 모니터로부터 내 눈을 보호하는 안경 아이디어 톡톡 인그라비도 블루라이트 차단 안경 외국계 쇼핑몰의 공습으로 국내 기업의 어려움이 가중되고 있습니다.\nURL: https://www.chosun.com/economy/startup_story/2024/04/23/IF7D3F7SBBEZVK6RGFUN5FSK6I/',
#    '[홍성용의 홍키자 빅테크] 핵무기보다 더 센놈 온다?… AGI가 인류 멸망시킨다면': 'Main Content: 내년 또는 2026년에는 인간보다 똑똑한 인공지능(AI)이 개발될 것이다." 일론 머스크 테슬라 최고경영자(CEO)가 최근 소셜미디어 엑스(X)와 진행한 인터뷰에서 밝힌 ...\nURL: https://www.mk.co.kr/news/it/10995869',
#    '[코인리더스] 애널리스트 "도지코인, 지금 매수해야"..DOGE 0.20달러 회복 가능성': 'Main Content: 암호화폐 커뮤니티에서 인지도가 높은 애널리스트인 알리 마르티네즈(Ali Martinez)가 X(구 트위터)를 통해 도지코인(Dogeecoin, DOGE) 가격 전망을 전했다.\nURL: https://www.coinreaders.com/107302',
#    '[쫌아는기자들] 고래를 소화하기 시작한 새우, 정육각의 초록마을 인수기': 'Main Content: 주3회 발행하는 뉴스레터 [쫌아는기자들] 입니다. 전문은 유료 구독자에게 공개. 유료 가입(https://page.stibee.com/subscriptions/158656).\nURL: https://www.chosun.com/economy/smb-venture/2024/04/22/XKVDREVW4JBVPOV3PVORU4ZBKM/',
#    '北 해킹 조직이 국내 방산업체 총공격… 10여곳 피해': 'Main Content: 北 해킹 조직이 국내 방산업체 총공격 10여곳 피해 북한 해킹조직 라자루스·안다리엘·김수키 국내 방산기술 탈취하려 합동공격 북한 해킹조직 3곳이 국내 방산기술 ...\nURL: https://www.chosun.com/national/national_general/2024/04/23/QSKHX4ANR5B23KYQVRY57YXDCI/',
#    '펀드스트랫 톰 리 “비트코인 올해 $15만, 장기적 $50만 가능”': 'Main Content: 펀드스트랫(Fundstrat)의 전략가이자 공동 설립자인 톰 리가 반감기 이후 비트코인(BTC)에 대한 낙관적인 전망을 확인했다. 22일(현지시간) CNBC와의 인터뷰에서 톰 리 ...\nURL: https://www.blockmedia.co.kr/archives/512069',
#    '비트코인 MVRV 비율, 90일 평균 아래 하락 ... 과거 사례는 평균 67% 상승 시사': 'Main Content: 비트코인 반감기 이후 비트코인 가격 전망에 대한 다양한 전망과 분석이 쏟아지는 가운데 비트코인의 MVRV(실현 가치 대비 시장 가치) 지표가 현재 매력적인 매수 기회 ...\nURL: https://www.blockmedia.co.kr/archives/512052',
#    '[비즈톡톡] 프리미엄 브랜드 집착하는 애플… “250달러 ‘초저가 아이폰’ 출시해야” - 조선비즈': 'Main Content: 애플, 아이폰SE4 출고가 400달러 이상 유지할 듯 “동남아·인도 시장 공략하지만 프리미엄 브랜드 이미지 희석 두려워해” XR·자율주행차·AI 등 신사업도 지지부진.\nURL: https://biz.chosun.com/it-science/ict/2024/04/22/SSMYOTYE5BCDBDMO57KHWJWCTY/',
#    '홍콩 암호화폐 거래소 해시키, 바이낸스 거래 중단': 'Main Content: [더구루=홍성일 기자] 홍콩 암호화폐 거래소 해시키(HashKey Exchange)가 글로벌 1위 암호화폐 거래소 바이낸스(Binance)와의 거래 서비스를 중단한다.\nURL: https://www.theguru.co.kr/news/article.html?no=69851',
#    "인텔 13ㆍ14세대 CPU 충돌 문제 '임시' 해결책": 'Main Content: 맞춤형 PC 제조업체인 팔콘 노스웨스트(Falcon Northwest)가 코어 i7-14700K, 코어 i9-13900K 등 일부 인텔 13~14세대 인텔 코어 CPU에서 나타나는 무작위 불안정 문제 ...\nURL: https://www.itworld.co.kr/news/334219',
#    '화웨이 기린 9010 vs 스냅드래곤 8 3세대와 비교해보니.. 성능 2배 차이': 'Main Content: 기린 9010 사양(출처:https://twitter.com/faridofanani96). 중국 통신 장비 업체 화웨이가 최근 발표한 퓨라(Pura) 70 시리즈에 탑재된 기린 9010 칩의 성능이 퀄컴 ...\nURL: https://kbench.com/?q=node/255210',
#    '[AI 만난 신약개발]① “생명의 재료 다루기 쉬워졌다”...신약 발굴 비용 10분의 1, 시간은 3분의 1로 - 조선비즈': 'Main Content: AI 만난 신약개발① 생명의 재료 다루기 쉬워졌다...신약 발굴 비용 10분의 1, 시간은 3분의 1로 2018년 구글 딥마인드 알파폴드 등장 연이어 로제타폴드·ESM폴드 나와 ...\nURL: https://biz.chosun.com/science-chosun/science/2024/04/22/N7C6WI3MBRDVZBQTZJANI34CXU/',
#    '페이코인, 업비트 재상장 할 수 있을까?[엠블록레터]': 'Main Content: [엠블록레터] 안녕하세요 엠블록레터의 승아입니다. 비트코인이 반감기를 이틀 앞두고 6만달러선을 오가고 있습니다. 사상 최고치에서 약 17% 하락하며 강세장이 끝난 ...\nURL: https://www.mk.co.kr/news/economy/10997349',
#    '"DSLR급 카메라 모듈"…LG이노텍, 2년 연속 미국 `에디슨 어워즈` 수상': "Main Content: LG이노텍은 광학 설계 기술을 적용한 스마트폰용 '고배율 광학식 연속줌 카메라 모듈'로 올해 에디슨 어워즈를 수상했다고 21일 밝혔다. 지난해에 이은 2년 연속 ...\nURL: https://dt.co.kr/contents.html?article_no=2024042102109932820002",
#    '‘달면 삼키고 쓰면 뱉는’ 태양광 사업자에 발전사 RPS 담당자 ‘한숨’': 'Main Content: 신재생에너지 공급인증서(REC) 가격이 고공행진을 이어가는 가운데 장기고정가격계약을 체결한 태양광 발전사업자들이 의무공급사인 발전사들을 대상으로 장기계약이 ...\nURL: https://www.electimes.com/news/articleView.html?idxno=335880',
#    '비트코인 현물 ETF 막고 2배 레버리지 허용이 투자자 보호?': 'Main Content: 한국 금융감독당국의 비트코인 관련 정책을 유심히 살펴보면 앞뒤가 맞지 않는 경우가 있다. 물론 하나하나 따져보면 다 법률과 부합하는 올바른 정책들이다.\nURL: https://www.blockmedia.co.kr/archives/511377',
#    '저커버그 "AI 학습 데이터보다 중요한 것은 피드백 루프"': 'Main Content: 마크 저커버그 메타 CEO가 빅테크 기업의 인공지능(AI) 훈련용 데이터 경쟁에 대해 중요한 것은 데이터를 확보하는 것뿐 아니라 이를 최대한 잘 활용하는 것이 중요 ...\nURL: https://www.aitimes.com/news/articleView.html?idxno=159008',
#    '산은, \'KDB 넥스트원 부산\' 신설…"동남권 스타트업 지원"': "Main Content: (서울=연합뉴스) 오지은 기자 = 산업은행이 동남권 유망 스타트업을 대상으로 육성 프로그램인 'KDB 넥스트원(NextONE) 부산'을 시행한다고 22일 밝혔다.\nURL: https://www.yna.co.kr/view/AKR20240422122000002"}}]

# %%
# run the GPT model with the updated messages
user_interested_category = "AI, 대규모 언어 모델"# 관심 주제 설정
language = "한국어" # 언어 설정
system_message = "너는 사람들의 관심사에 맞는 오늘의 뉴스를 간결하고 재미있게 요약해서 전달하는 뉴스 앵커야."# 뉴스 앵커로서 관심사에 맞는 뉴스 요약 제공 역할 부여
user_message = f"""
나의 관심 주제는 {user_interested_category}이야.
나는 {language}로 된 뉴스를 원해.
아래 삼중 따옴표 안에 오늘의 뉴스를 제공할게.
Key는 뉴스의 제목, Value는 뉴스의 내용으로 구성되어 있어.
다양한 주제 중에 너가 가장 중요하다고 생각되는 대표적인 주제 7가지를 뽑아서 내가 이해하기 쉽도록 비슷한 주제끼리 묶어서 요약해줘.
단, 요약을 할 땐 일반적인 내용이 아닌 구체적인 정보를 포함해서 제공해야해.
사용자가 읽기 쉽도록 위트를 섞어서 재미있게 정보를 전달해줘.

\"\"\"{messages[-1]['content']}\"\"\"
"""

# 관심 주제를 뉴스 카테고리로 변환 요청 및 해당 언어의 뉴스 요약 요청
# 위에서 생성한 뉴스 데이터 결과를 제공
# 뉴스 데이터에서 중요 주제 7개 선정 후 요약을 요청
# 단, 구체적 정보와 위트를 요약에 포함할 것을 요청

model = "gpt-4-turbo"
max_token = 3000
messages = [
    {"role": "system", "content": system_message},
    {"role": "user", "content": user_message}
]

# %%
# streaming
response = run_gpt(model, messages, max_token=max_token, stream=True)
for chunk in response:
    print(chunk)
    print(chunk.choices[0].delta.content)
    print("****************")
# Out:
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='', function_call=None, role='assistant', tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='안', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 안
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='녕', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 녕
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='하세요', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 하세요
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=',', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# ,
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 여', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  여
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='러', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 러
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='분', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 분
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='의', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 의
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' AI', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  AI
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 뉴', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  뉴
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='스', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 스
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 앵', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  앵
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='커', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 커
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='가', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 가
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 오', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  오
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='늘', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 늘
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='의', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 의
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 핫', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  핫
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 토픽', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  토픽
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='을', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 을
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 살', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  살
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='펴', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 펴
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='보', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 보
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='았', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 았
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='습니다', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 습니다
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='.', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# .
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 오', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  오
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='늘', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 늘
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='은', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 은
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 디', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  디
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='지', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 지
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='털', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 털
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 세', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  세
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='계', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 계
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='의', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 의
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 변', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  변
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='화', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 화
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='부', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 부
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='터', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 터
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 전', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  전
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='자', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 자
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='기', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 기
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='기', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 기
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='의', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 의
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 새', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  새
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='로', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 로
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='운', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 운
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 도', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  도
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='약', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 약
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='까', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 까
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='지', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 지
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 다', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  다
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='양', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 양
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='한', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 한
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 뉴', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  뉴
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='스', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 스
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='가', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 가
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 있', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  있
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='었', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 었
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='는', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 는
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='데', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 데
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='요', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 요
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=',', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# ,
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 중', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  중
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='요', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 요
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='한', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 한
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 주', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  주
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='제', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 제
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='들', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 들
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='을', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 을
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 재', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  재
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='미', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 미
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='있', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 있
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='게', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 게
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 요', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  요
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='약', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 약
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='해', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 해
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='드', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 드
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='리', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 리
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='겠', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 겠
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='습니다', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 습니다
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='.', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# .
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 준', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  준
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='비', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 비
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='되', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 되
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='셨', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 셨
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='나', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 나
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='요', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 요
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='?', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# ?
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' Let', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  Let
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content="'s", function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 's
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' dive', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  dive
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' in', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  in
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='!\n\n', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# !
#
#
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='1', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 1
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='.', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# .
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' **', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  **
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='AI', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# AI
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='와', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 와
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 기', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  기
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='술', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 술
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 혁', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  혁
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='신', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 신
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='**', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# **
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=':\n', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# :
#
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='   ', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' -', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  -
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' **', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  **
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='AI', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# AI
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 전', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  전
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='투', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 투
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='기', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 기
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='가', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 가
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 온', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  온
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='다', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 다
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='**:', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# **:
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 미', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  미
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='국', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 국
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='에서', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 에서
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' AI', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  AI
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='가', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 가
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 조', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  조
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='종', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 종
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='하는', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 하는
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' F', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  F
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='-', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# -
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='16', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 16
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 전', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  전
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='투', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 투
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='기', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 기
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='가', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 가
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 인', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  인
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='간', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 간
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 조', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  조
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='종', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 종
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='사', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 사
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='와', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 와
# ****************
# ...
# 의
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 디', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  디
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='지', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 지
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='털', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 털
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 뉴', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  뉴
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='스', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 스
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='를', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 를
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 모', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  모
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='두', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 두
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 전', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  전
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='달', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 달
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='드', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 드
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='렸', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 렸
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='습니다', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 습니다
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='.', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# .
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 기', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  기
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='술', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 술
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='의', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 의
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 발', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  발
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='전', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 전
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='이', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 이
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 우', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  우
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='리', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 리
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 일', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  일
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='상', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 상
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='에', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 에
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 어', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  어
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='떤', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 떤
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 새', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  새
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='로', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 로
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='운', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 운
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 변', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  변
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='화', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 화
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='를', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 를
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 가져', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  가져
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='올', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 올
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='지', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 지
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=',', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# ,
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 계', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  계
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='속', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 속
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='해서', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 해서
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=' 지', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
#  지
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='켜', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 켜
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='봐', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 봐
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='주세요', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# 주세요
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content='!', function_call=None, role=None, tool_calls=None), finish_reason=None, index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# !
# ****************
# ChatCompletionChunk(id='chatcmpl-9H4J70nTDBA0fBliUjI1KotydKKqw', choices=[Choice(delta=ChoiceDelta(content=None, function_call=None, role=None, tool_calls=None), finish_reason='stop', index=0, logprobs=None)], created=1713855161, model='gpt-4-turbo-2024-04-09', object='chat.completion.chunk', system_fingerprint='fp_76f018034d')
# None
# ****************

# %% [markdown]
# # Mini Project 3
